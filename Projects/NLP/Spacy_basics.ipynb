# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(u'Although commmonly attributed to John Lennon from his song "Beautiful Boy", \
the phrase "Life is what happens to us while we are making other plans" was written by \
cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')

# %%
doc2 = nlp(u'This is the first sentence. This is another sentence. This is the last sentence.')

# %%
for sentence in doc2.sents:
    print(sentence)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence.

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7fc70654b390>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7fc705866708>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7fc705866768>)]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# ## Tokenization
#
# Process of breaking the original text into component pieces (tokens)
# Basic building blocks of doc object

# %%
mystring = '"We\'re moving to L.A. !"'

# %%
print(mystring)
# Out:
# "We're moving to L.A. !"

# %%
doc = nlp(mystring)

# %%
for token in doc:
    print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com")

# %%
for t in doc2:
    print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com

# %%
len(doc2)
# Out:
# 18

# %%
doc2.vocab

# %%
len(doc2.vocab)
# Out:
# 533

# %%
doc2[2]
# Out:
# here

# %%
doc[3:9]
# Out:
# moving to L.A. !"

# %% [markdown]
# Doc objects cannot be reassigned

# %%
doc3 = nlp(u"Apple to build a Hong Kong factory for $6 million")

# %%
for token in doc3:
    print(token.text, end=" | ")
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |

# %%
for entity in doc3.ents:
    print(entity)
    print(entity.label_)
    print(str(spacy.explain(entity.label_)))
    print("\n")
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
#
# Hong Kong
# GPE
# Countries, cities, states
#
#
# $6 million
# MONEY
# Monetary values, including unit

# %% [markdown]
# Spacy is smart enough to recognize names.

# %%
doc4 = nlp(u"Autonomous cars shift insurance liability towards manufacturers.")

# %%
for chunk in doc4.noun_chunks:
    print(chunk)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %% [markdown]
# ## Tokenization visualized

# %%
from spacy import displacy

# %%
doc5 = nlp(u"Apple is going to build a U.K. factory for $6 million")

# %%
displacy.render(doc5, style="dep",jupyter = True, options={"distance":70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a819507868ef41159235ab9abb8b751e-0" class="displacy" width="890" height="277.0" direction="ltr" style="max-width: none; height: 277.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-0" stroke-width="2px" d="M70,142.0 C70,72.0 180.0,72.0 180.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,144.0 L62,132.0 78,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-1" stroke-width="2px" d="M140,142.0 C140,107.0 175.0,107.0 175.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M140,144.0 L132,132.0 148,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-2" stroke-width="2px" d="M280,142.0 C280,107.0 315.0,107.0 315.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280,144.0 L272,132.0 288,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-3" stroke-width="2px" d="M210,142.0 C210,72.0 320.0,72.0 320.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,144.0 L328.0,132.0 312.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-4" stroke-width="2px" d="M420,142.0 C420,72.0 530.0,72.0 530.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,144.0 L412,132.0 428,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-5" stroke-width="2px" d="M490,142.0 C490,107.0 525.0,107.0 525.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490,144.0 L482,132.0 498,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-6" stroke-width="2px" d="M350,142.0 C350,37.0 535.0,37.0 535.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,144.0 L543.0,132.0 527.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab9abb8b751e-0-7" stroke-width="2px" d="M350,142.0 C350,2.0 610.0,2.0 610.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a819507868ef41159235ab9abb8b751e-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,144.0 L618.0,132.0 602.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a819507868ef41159235ab

# %%
doc6 = nlp(u"Over the last quarter Apple sold nearly 20 thousands iPods for profit for $6 million")

# %%
displacy.render(doc6, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for profit for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# # Stemming

# %% [markdown]
# *   Process of finding base words. For example base word of boating can boat.
# *   Chops off ends of words until the base/root (stem) word is achieved
#
# *   Popular stemming algorithms - Porter and Porter 2
# *   Spacy does not have any stemming methods, so we will use nltk

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ["run","runner","ran","runs","easily","fairly"]

# %%
for word in words:
    print(word+"----->"+p_stemmer.stem(word))
# Out:
# run----->run
# runner----->runner
# ran----->ran
# runs----->run
# easily----->easili
# fairly----->fairli

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer = SnowballStemmer(language="english")

# %%
for word in words:
    print(word+"----->"+s_stemmer.stem(word))
# Out:
# run----->run
# runner----->runner
# ran----->ran
# runs----->run
# easily----->easili
# fairly----->fair

# %%
words = ["generous","generation","generously","generate"]

# %%
for word in words:
    print(word+"----->"+s_stemmer.stem(word))
# Out:
# generous----->generous
# generation----->generat
# generously----->generous
# generate----->generat

# %% [markdown]
# # Lemmatization

# %% [markdown]
# * Much more sophisticated than stemming
# * Looks beyond text reduction and it is much more informative
# * Spacy only has lemmatization libraries
# * For example lemma of mice is mouse

# %%
doc1 = nlp(u"I am a runner running in a race because I love to run since I ran today")

# %%
for token in doc1:
    print(token.text, "\t",token.pos_,"\t",token.lemma,"\t",token.lemma_)
# Out:
# I 	 PRON 	 561228191312463089 	 -PRON-
# am 	 AUX 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# running 	 VERB 	 12767647472892411841 	 run
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# I 	 PRON 	 561228191312463089 	 -PRON-
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# I 	 PRON 	 561228191312463089 	 -PRON-
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %% [markdown]
# You can see running, ran is reduced to lemma run.

# %%
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
doc2 = nlp(u"I saw ten mice today!")

# %%
show_lemmas(doc2)
# Out:
# I            PRON   561228191312463089     -PRON-
# saw          VERB   11925638236994514241   see
# ten          NUM    7970704286052693043    ten
# mice         NOUN   1384165645700560590    mouse
# today        NOUN   11042482332948150395   today
# !            PUNCT  17494803046312582752   !

# %% [markdown]
# # Stop words

# %% [markdown]
# * Words like "a" and "the" does not require any tagging and is removed before processing
#
# * Spacy has built-in 305 stop words

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'something', 'nevertheless', 'whose', 'used', 'go', 'such', 'per', 'every', 'whither', 'towards', 'another', 'off', 'nor', 'whoever', "'s", '‘m', 'therefore', 'three', 'back', 'and', 'have', 'me', 'thence', 'while', 'show', 'they', 'anyway', 'must', 'you', 'latter', 'am', 'wherein', 'is', 'perhaps', 'sixty', 'part', 'side', 'thereafter', 'becoming', 'made', '’m', 'their', 'nine', 'until', 'seem', 'someone', 'whenever', 'than', 'does', 'for', 'neither', 'thereby', 'was', 'whatever', 'everything', 'at', 'yours', 'too', 'none', 'front', 'take', 'noone', 'any', 'did', 'throughout', 'who', 'several', 'she', 'eight', 'somehow', 'within', 'seemed', 'are', 'just', 'many', 'through', 'might', 'done', 'one', 'sometimes', 'in', 'onto', 'around', 'therein', 'whereas', '’ll', 'without', 'because', 'almost', 'though', 'using', 'were', 'most', 'i', 'keep', 'less', 'very', 'please', 're', 'would', 'ever', 'where', 'yourself', "'m", 'been', 'latterly', 'either', 'somewhere', 'whether', 'alone', 'before', 'see', 'n‘t', 'give', 'these', '‘re', 'ca', 'few', 'since', "'re", '‘ll', 'next', 'behind', 'anyhow', 'herein', 'may', 'beyond', 'them', 'which', "n't", 'here', 'being', 'formerly', 'always', 'had', 'also', 'hereafter', 'how', 'least', 'anywhere', 'do', 'whence', 'mostly', 'make', 'two', 'indeed', 'we', 'elsewhere', 'toward', 'top', 'five', 'against', 'besides', 'n’t', 'mine', 'only', 'along', 'moreover', 'quite', 'so', 'thus', 'has', 'now', "'d", '‘s', 'own', 'up', 'rather', 'upon', 'if', 'ours', 'then', 'together', 'namely', 'this', 'amongst', 'between', 'can', 'anything', 'bottom', 'hence', 'move', 'never', 'hers', 'further', 'already', 'my', 'everyone', 'once', 'whereafter', '‘ve', 'put', 'his', 'us', 'there', 'during', 'name', 'thereupon', 'although', 'when', 'former', 'get', 'below', 'via', "'ll", 'be', 'to', '’s', 'as', "'ve", '‘d', 'forty', 'again', 'myself', 'above', 'among', 'your', 'thru', 'a', '’ve', 'really', 'across', 'first', 'unless', 'its', 'the', 'that', 'our', 'after', 'nobody', 'over', 'whole', 'or', 'fifteen', 'themselves', 'yet', 'not', 'hundred', 'beside', 'down', 'eleven', 'much', 'other', 'regarding', 'same', 'seems', 'due', 'sometime', 'itself', 'hereupon', 'often', 'more', 'third', 'could', 'both', 'still', 'it', 'nothing', 'beforehand', 'otherwise', 'why', 'into', 'became', 'nowhere', 'doing', 'empty', 'even', 'each', 'some', 'should', 'whereby', 'last', 'become', 'anyone', 'hereby', 'what', 'say', 'various', 'about', 'others', 'with', 'ourselves', 'her', 'on', 'ten', 'fifty', 'seeming', 'under', 'wherever', 'enough', 'six', 'himself', 'call', 'however', 'those', 'four', 'by', 'cannot', 'meanwhile', 'twelve', 'from', 'but', '’re', 'out', 'well', 'no', 'yourselves', 'becomes', 'full', 'everywhere', 'whereupon', 'except', 'an', 'afterwards', 'all', 'else', 'twenty', 'herself', 'whom', 'him', 'of', 'will', 'amount', 'he', '’d', 'serious'}

# %%
print(len(nlp.Defaults.stop_words))
# Out:
# 326

# %%
nlp.vocab["is"].is_stop
# Out:
# True

# %%
# Let us add btw (by the way) into the default stop words.

nlp.Defaults.stop_words.add("btw")

# %%
nlp.vocab["btw"].is_stop = True

# %%
print(len(nlp.Defaults.stop_words))     # btw added
# Out:
# 327

# %% [markdown]
# # Phrase matching and vocabulary

# %% [markdown]
# We will identify and label specific phrases that match patterns we can define ourselves.

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)

# %% [markdown]
# Spacey offers a rule matching tool called matcher and that allows you to build a library of token patterns then match those patterns against a doc object to return a list of found matches.

# %%
# We will read a document and we are going to find solar power.

# If we transform the word Solarpower into lowercase, we must be able to find it
pattern1 = [{"LOWER":'solarpower'}] 

# Solar-power
pattern2 = [{"LOWER":'solar'},{"IS_PUNCT":True},{'LOWER':'power'}]

# Solar power
pattern3 = [{"LOWER":'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower', None, pattern1, pattern2, pattern3)

# %%
doc = nlp(u"The Solar Power industry continues to grow as solarpower increases. Solar-power is amazing.")

# %%
found_matches = matcher(doc)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 8, 9), (8656102463236116519, 11, 14)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 8 9 solarpower
# 8656102463236116519 SolarPower 11 14 Solar-power

# %%
# Let us remove these patterns

matcher.remove('SolarPower')

# %%
# This is going to find solarpower SolarPower
pattern1 = [{"LOWER":'solarpower'}] 

# This is going to find solar(* Any kind of punctuation)power
pattern2 = [{"LOWER":'solar'},{"IS_PUNCT":True,'OP':'*'},{'LOWER':'power'}] # Allows the pattern to match multiple times

# %%
matcher.add('SolarPower',None,pattern1, pattern2)

# %%
doc2 = nlp(u"Solar--power is solarpower yay!")

# %%
found_matches = matcher(doc2)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 4, 5)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc2[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 0 3 Solar--power
# 8656102463236116519 SolarPower 4 5 solarpower

# %%
from spacy.matcher import PhraseMatcher

# %%
matcher = PhraseMatcher(nlp.vocab)

# %%
with open("reaganomics.txt",encoding='cp1252') as f:
    doc3 = nlp(f.read())

# %%
phrase_list = ["voodoo economics","supply-side economics","tricle-down economics","free-market economics"]

# %%
phrase_patterns = [nlp(text) for text in phrase_list] # Creating a doc object of the patterns in the above list

# %%
matcher.add('EconMatcher',None,*phrase_patterns)

# %%
found_matches = matcher(doc3)

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc3[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 3680293220734633682 EconMatcher 41 45 supply-side economics
# 3680293220734633682 EconMatcher 54 56 voodoo economics
# 3680293220734633682 EconMatcher 61 65 free-market economics
# 3680293220734633682 EconMatcher 673 677 supply-side economics

# %%
# Let us see the association of words OR let us see the words around our defined pattern

for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc3[start-5:end+5]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 3680293220734633682 EconMatcher 41 45 policies are commonly associated with supply-side economics, referred to as trickle
# 3680293220734633682 EconMatcher 54 56 trickle-down economics or voodoo economics by political opponents, and
# 3680293220734633682 EconMatcher 61 65 by political opponents, and free-market economics by political advocates.
#
#
# 3680293220734633682 EconMatcher 673 677 attracted a following from the supply-side economics movement, which formed in

# %%
for i in found_matches:
    print(i)
    print(i[1])
    print(doc[1])
    break
# Out:
# (3680293220734633682, 41, 45)
# 41
# Solar

# %%
from collections import defaultdict

# %%
x = defaultdict(list,{'chicken parmigiana': [4, 5, 4, 5, 5,5, 5, 5,4,4,4,3,4,5,5,4,5],'steak and cheese': [5, 5, 5, 5, 4, 5, 5, 5, 5]})

# %%
y = {}
for i,j in x.items():
    print(sum(j)/len(j))
    y[i] = sum(j)/len(j)
# Out:
# 4.470588235294118
# 4.888888888888889

# %%
print(y.values())
# Out:
# dict_values([4.470588235294118, 4.888888888888889])

# %%
min(y.values())
# Out:
# 4.470588235294118
